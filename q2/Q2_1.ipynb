# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('nlp_hackathon_search.csv')

# %%
df.columns
# Out:
# Index(['document', 'question', 'title', 'document_id'], dtype='object')

# %%
df.sample(5)
# Out:
#                                                 document  \
# 50706  The concept's origins can potentially be trace...
# 12273  At the time of Harold Evans' appointment as ed...
# 55505  Violent incidents occurred throughout the Pied...
# 31635  A comprehensive school is a state school that ...
# 46071  The reproductive system of female insects cons...
#
#                                                 question  \
# 50706           When did Jewish law recognize copyright?
# 12273  What is the name of the highest-selling tabloi...
# 55505         The Cainhoy Incident occurred on what day?
# 31635  What countries used comprehensive schools exte...
# 46071  Female insects reproductive system contain a p...
#
#                             title                       document_id
# 50706       Intellectual_property  428f72f61bfe11ea8f2b656571b1b549
# 12273                   The_Times  427072701bfe11ea8f2b656571b1b549
# 55505  Charleston,_South_Carolina  429733881bfe11ea8f2b656571b1b549
# 31635        Comprehensive_school  426aa0d41bfe11ea8f2b656571b1b549
# 46071                      Insect  429348d61bfe11ea8f2b656571b1b549

# %%
df = df.dropna()

# %%
X_train = df['question']
Y_train = df['document_id']

# %%
import re
def clean_str(string):
    string = re.sub(r"[^A-Za-z0-9 ]", " ", string)
    string = re.sub(r"\'s", "", string)
    string = re.sub(r"\'ve", " \'ve", string)
    string = re.sub(r"n\'t", " n\'t", string)
    string = re.sub(r"\'re", " \'re", string)
    string = re.sub(r"\'d", " \'d", string)
    string = re.sub(r"\'ll", " \'ll", string)
    string = re.sub(r",", " , ", string)
    string = re.sub(r"\s{2,}", " ",string)
    return string

# %%
X_train = [clean_str(str(x)) for x in X_train]

# %%
words_count = {}
for t in X_train:
    for w in t.split():
        if w not in words_count:
            words_count[w] = 1
        else:
            words_count[w] += 1

# %%
words_count
# Out:
# {'What': 26685,
#  'kind': 543,
#  'of': 24402,
#  'scores': 17,
#  'did': 11433,
#  'Twilight': 59,
#  'Princess': 76,
#  'receive': 189,
#  'from': 2638,
#  'many': 4024,
#  'video': 113,
#  'game': 209,
#  'review': 25,
#  'sources': 44,
#  'is': 11373,
#  'the': 44111,
#  'date': 380,
#  'that': 3142,
#  'Cyrpus': 1,
#  'attained': 7,
#  'independence': 98,
#  'How': 5885,
#  'long': 574,
#  'Lord': 50,
#  'Salisbury': 3,
#  'remain': 60,
#  'as': 2575,
#  'Prime': 60,
#  'Minister': 83,
#  'purpose': 128,
#  'antibiotic': 12,
#  'treatment': 43,
#  'other': 1066,
#  'species': 225,
#  'can': 1095,
#  'be': 2133,
#  'seen': 106,
#  'close': 80,
#  'to': 13134,
#  'shores': 5,
#  'Norfolk': 111,
#  'Island': 173,
#  'Whit': 1,
#  'what': 9330,
#  'donors': 7,
#  'does': 3128,
#  'zinc': 100,
#  'form': 350,
#  'stable': 16,
#  'complexes': 3,
#  'companies': 128,
#  'a': 7567,
#  'judge': 61,
#  'say': 212,
#  'infringed': 2,
#  'on': 3076,
#  'Dr': 15,
#  'Moustakas': 1,
#  's': 6090,
#  'prior': 96,
#  'blue': 34,
#  'light': 172,
#  'patent': 60,
#  'in': 15745,
#  '2015': 126,
#  'When': 3913,
#  'was': 12742,
#  'Peterson': 3,
#  'born': 131,
#  'In': 3143,
#  'country': 693,
#  'Butrint': 4,
#  'are': 3739,
#  'British': 460,
#  'prime': 40,
#  'ministers': 19,
#  'part': 653,
#  'grants': 14,
#  'them': 152,
#  'title': 200,
#  'Right': 9,
#  'Honourable': 2,
#  'pattern': 24,
#  'data': 89,
#  'stored': 34,
#  'CD': 57,
#  'believed': 134,
#  'would': 594,
#  'happen': 118,
#  'if': 188,
#  'Chinese': 204,
#  'entered': 26,
#  'conflict': 99,
#  'result': 213,
#  'child': 116,
#  'having': 94,
#  'an': 1598,
#  'African': 133,
#  'mother': 99,
#  'The': 2187,
#  'bombers': 21,
#  'used': 1484,
#  'out': 371,
#  'desperation': 1,
#  'Which': 2898,
#  'street': 83,
#  'runs': 47,
#  'FDR': 3,
#  'Drive': 13,
#  'Eleventh': 1,
#  'Avenue': 51,
#  'type': 1492,
#  'motor': 63,
#  'trailway': 1,
#  'traction': 7,
#  'applications': 30,
#  'serves': 34,
#  'collective': 10,
#  'Head': 13,
#  'State': 101,
#  'Phil': 3,
#  'Skinner': 2,
#  'awarded': 50,
#  'MBE': 4,
#  'flag': 40,
#  'removed': 66,
#  'club': 106,
#  'crest': 19,
#  'month': 137,
#  'and': 5029,
#  'year': 2458,
#  'Chopin': 377,
#  'give': 160,
#  'his': 959,
#  'final': 117,
#  'performance': 54,
#  'percent': 149,
#  'whites': 22,
#  'Who': 5878,
#  'wrote': 259,
#  'Divine': 5,
#  'Comedy': 5,
#  'types': 210,
#  'stakeholders': 1,
#  'consulted': 3,
#  'bill': 41,
#  'enact': 14,
#  'National': 155,
#  'Communications': 6,
#  'Act': 154,
#  'ordered': 41,
#  'Valencia': 96,
#  'punished': 2,
#  'for': 5183,
#  'supporting': 20,
#  'Charles': 84,
#  'Bush': 42,
#  'declare': 41,
#  'Iraq': 41,
#  'war': 473,
#  'Upon': 11,
#  'inhalation': 1,
#  'percentage': 580,
#  'fresh': 12,
#  'air': 151,
#  'bypasses': 1,
#  'lungs': 12,
#  'flows': 9,
#  'directly': 34,
#  'into': 652,
#  'posterior': 1,
#  'sac': 2,
#  'theme': 39,
#  'common': 302,
#  'Spielberg': 114,
#  'films': 58,
#  'paired': 7,
#  'with': 2927,
#  'any': 157,
#  'allele': 2,
#  'same': 147,
#  'trait': 19,
#  'do': 2123,
#  'dominant': 51,
#  'alleles': 11,
#  'rise': 84,
#  'Sun': 103,
#  'favor': 39,
#  'withdrawal': 15,
#  'European': 275,
#  'Union': 154,
#  'Where': 2372,
#  'George': 111,
#  'Washington': 148,
#  'planning': 19,
#  'go': 167,
#  'after': 879,
#  'staying': 7,
#  'New': 865,
#  'Haven': 331,
#  'Greeks': 58,
#  'look': 51,
#  'down': 135,
#  'upon': 89,
#  'Under': 93,
#  'whom': 247,
#  'Western': 114,
#  'Umayyad': 14,
#  'Caliphate': 8,
#  'empire': 164,
#  'gain': 93,
#  'its': 759,
#  'genre': 60,
#  'music': 417,
#  'Uffie': 1,
#  'perform': 88,
#  'average': 216,
#  'speed': 69,
#  'winning': 40,
#  'solar': 125,
#  'powered': 29,
#  'car': 31,
#  'by': 2622,
#  '2007': 191,
#  'contestants': 53,
#  'moved': 75,
#  'forward': 19,
#  'each': 250,
#  'round': 32,
#  'towers': 15,
#  'typically': 149,
#  'found': 450,
#  'west': 79,
#  'front': 39,
#  'French': 338,
#  'cathedrals': 18,
#  'On': 478,
#  'day': 299,
#  'it': 1070,
#  'announced': 56,
#  'CBC': 17,
#  'had': 783,
#  'lost': 99,
#  'exclusve': 1,
#  'rights': 118,
#  'curling': 2,
#  'broadcasting': 23,
#  'manages': 11,
#  'farmers': 30,
#  'market': 127,
#  'Brazilian': 13,
#  'constitution': 73,
#  'not': 777,
#  'have': 2075,
#  'supremacy': 7,
#  'clause': 18,
#  'interest': 68,
#  'relation': 65,
#  'between': 651,
#  'state': 608,
#  'legislation': 34,
#  'legal': 93,
#  'agreements': 27,
#  'critically': 4,
#  'important': 239,
#  'discussion': 15,
#  'rules': 70,
#  'laws': 124,
#  'economy': 134,
#  'element': 65,
#  'made': 613,
#  'Oasis': 1,
#  'unique': 49,
#  'among': 164,
#  '1990s': 30,
#  'Britpop': 1,
#  'bands': 42,
#  'linguistic': 18,
#  'regions': 65,
#  'Switzerland': 117,
#  'their': 1061,
#  'own': 127,
#  'local': 118,
#  'dialect': 83,
#  'thickness': 10,
#  'Antartican': 1,
#  'glacier': 14,
#  'traditional': 95,
#  'use': 872,
#  'falekaupule': 3,
#  'first': 2001,
#  'undergraduate': 16,
#  'woman': 44,
#  'at': 1589,
#  'Yale': 147,
#  'hosted': 41,
#  '1998': 35,
#  'Winter': 10,
#  'Olympics': 44,
#  'Previous': 4,
#  '1725': 2,
#  'subject': 71,
#  'matter': 54,
#  'focused': 34,
#  'concours': 2,
#  'academiques': 2,
#  'Quran': 89,
#  'widely': 51,
#  'accepted': 36,
#  'historians': 32,
#  'contain': 77,
#  'relatively': 12,
#  'accurate': 20,
#  'record': 163,
#  'whose': 92,
#  'words': 76,
#  'named': 211,
#  'Madonna': 174,
#  'top': 151,
#  'female': 91,
#  'touring': 5,
#  'artist': 93,
#  'all': 418,
#  'time': 738,
#  'Whitlam': 2,
#  'House': 115,
#  'Representatives': 8,
#  'three': 247,
#  'factors': 59,
#  'scientists': 63,
#  'believe': 264,
#  'cause': 251,
#  'sexual': 88,
#  'orientation': 48,
#  'name': 1929,
#  'river': 104,
#  'through': 206,
#  'Detroit': 116,
#  'total': 120,
#  'immune': 26,
#  'system': 602,
#  'generally': 84,
#  'composed': 53,
#  'structures': 37,
#  'people': 1148,
#  'live': 240,
#  'Federal': 77,
#  'District': 26,
#  '1647': 1,
#  'how': 1029,
#  'factories': 11,
#  'company': 391,
#  'most': 1202,
#  'popular': 234,
#  'method': 113,
#  'travel': 95,
#  'citizens': 77,
#  'world': 409,
#  'bulk': 5,
#  'carriers': 41,
#  'Greece': 208,
#  'earliest': 104,
#  'known': 665,
#  'writing': 74,
#  'about': 692,
#  'dye': 13,
#  'Aermenian': 1,
#  'cochineal': 3,
#  'theorbo': 1,
#  'Baroque': 19,
#  'instrument': 68,
#  'fell': 17,
#  'disuse': 2,
#  'only': 357,
#  'Communist': 25,
#  'allowed': 165,
#  'embassy': 12,
#  'Stroessner': 1,
#  'Paraguay': 1,
#  'Major': 11,
#  'League': 242,
#  'Soccer': 1,
#  'franchise': 10,
#  'based': 324,
#  'York': 295,
#  'religion': 240,
#  'Popper': 106,
#  'family': 148,
#  'observe': 20,
#  'during': 913,
#  'youth': 14,
#  'has': 1280,
#  'been': 682,
#  'heavily': 27,
#  'restricted': 24,
#  'until': 118,
#  'recently': 40,
#  'stems': 4,
#  'cacti': 2,
#  'rival': 26,
#  'foothold': 2,
#  'attempted': 30,
#  'Bolama': 2,
#  'population': 640,
#  'Greater': 21,
#  '2010': 250,
#  'hosts': 18,
#  'parasites': 8,
#  'song': 197,
#  'Beyonc': 179,
#  'fifth': 24,
#  'studio': 26,
#  'album': 184,
#  'featured': 81,
#  'her': 284,
#  'husband': 9,
#  'Richmond': 128,
#  'located': 759,
#  'line': 162,
#  'James': 77,
#  'Sichuan': 56,
#  'delineated': 2,
#  'mountain': 63,
#  'range': 113,
#  'At': 267,
#  'event': 292,
#  'biodiversity': 14,
#  'research': 129,
#  'paper': 89,
#  'presented': 31,
#  'busiest': 22,
#  'bridge': 30,
#  'cars': 25,
#  'unemployment': 28,
#  'rate': 201,
#  'Armenia': 102,
#  'Was': 73,
#  'U': 290,
#  'Wisara': 2,
#  'able': 148,
#  'survive': 21,
#  'protest': 44,
#  'Since': 62,
#  'when': 904,
#  'Indigenous': 7,
#  'Australians': 3,
#  'referred': 129,
#  'black': 115,
#  'described': 84,
#  'living': 97,
#  'coast': 47,
#  'Celtic': 8,
#  'South': 206,
#  'East': 164,
#  'Asia': 69,
#  'term': 600,
#  'commonly': 123,
#  'refer': 101,
#  'Min': 7,
#  'nan': 1,
#  'dialects': 68,
#  'pro': 9,
#  'Tibetan': 53,
#  'protesters': 30,
#  'get': 307,
#  'together': 71,
#  'Different': 3,
#  'documents': 25,
#  'represent': 80,
#  'original': 194,
#  'text': 80,
#  'called': 906,
#  'LEDs': 56,
#  'theaters': 12,
#  'gained': 28,
#  'control': 233,
#  'Ionian': 2,
#  'Islands': 129,
#  '1809': 2,
#  'Besides': 122,
#  'County': 39,
#  'Cricket': 7,
#  'Ground': 7,
#  'cricket': 7,
#  'ground': 60,
#  'Hampshire': 15,
#  'Club': 51,
#  'play': 226,
#  'Alexander': 52,
#  'planned': 46,
#  'colonized': 11,
#  'eastern': 51,
#  'bank': 29,
#  'Persian': 32,
#  'Gulf': 16,
#  'ethnicity': 50,
#  'colonist': 3,
#  'established': 259,
#  'early': 307,
#  'settlements': 22,
#  'Florida': 70,
#  'fight': 66,
#  'teh': 5,
#  'Nagorno': 2,
#  'Karabakh': 3,
#  'War': 351,
#  'Romans': 74,
#  'adapt': 9,
#  'several': 66,
#  'religious': 175,
#  'convictions': 4,
#  'language': 582,
#  'Lower': 6,
#  'Canada': 97,
#  'speak': 85,
#  'routes': 15,
#  'Nanjing': 142,
#  'airport': 97,
#  'run': 124,
#  'dimensions': 11,
#  'glaciers': 28,
#  'ice': 38,
#  'sheets': 4,
#  'or': 796,
#  'continental': 19,
#  'According': 207,
#  '2012': 146,
#  'census': 85,
#  'Tuvalu': 142,
#  'islands': 55,
#  'Christ': 35,
#  'which': 1677,
#  'Christian': 97,
#  'figure': 53,
#  'were': 3178,
#  'often': 338,
#  'painted': 24,
#  'red': 108,
#  'medieval': 41,
#  'painting': 12,
#  'stretch': 14,
#  'railroad': 20,
#  'vital': 11,
#  'confederates': 1,
#  'civil': 72,
#  'Fr': 91,
#  'd': 127,
#  'ric': 91,
#  'Sand': 32,
#  'move': 106,
#  '1842': 8,
#  'buildings': 90,
#  'next': 63,
#  'reverse': 10,
#  'migration': 56,
#  'lead': 152,
#  'island': 160,
#  'City': 424,
#  'highest': 188,
#  'point': 123,
#  'Shuman': 5,
#  'patented': 11,
#  'engine': 16,
#  'mass': 80,
#  'produced': 170,
#  'transistor': 24,
#  'fixed': 16,
#  'genes': 67,
#  'demonstrate': 19,
#  'differences': 49,
#  'wolf': 9,
#  'dog': 81,
#  'researched': 7,
#  'role': 141,
#  'emotional': 18,
#  'phenotype': 7,
#  'temperaments': 2,
#  'social': 125,
#  'connectedness': 1,
#  'city': 907,
#  'Hadik': 2,
#  'occupy': 26,
#  'power': 343,
#  'destroy': 26,
#  'bad': 27,
#  'karma': 9,
#  'Alpine': 13,
#  'countries': 320,
#  'see': 132,
#  'influx': 10,
#  'poets': 5,
#  'artists': 55,
#  'musicians': 13,
#  'Mali': 25,
#  'new': 574,
#  'Sir': 26,
#  'Francis': 35,
#  'Drake': 13,
#  'death': 248,
#  'some': 559,
#  'Swedish': 13,
#  'sleaze': 1,
#  'metal': 64,
#  'revivalist': 2,
#  'build': 89,
#  'number': 273,
#  'Windows': 92,
#  '8': 78,
#  'Release': 4,
#  'Preview': 6,
#  'Americans': 107,
#  'lived': 112,
#  'Boston': 144,
#  'proper': 25,
#  '2013': 175,
#  'Why': 856,
#  'Kathmandu': 80,
#  'mainly': 45,
#  'via': 35,
#  'automobile': 9,
#  'aircraft': 140,
#  'West': 224,
#  'Raleigh': 60,
#  'Axons': 2,
#  'send': 73,
#  'signals': 21,
#  'person': 202,
#  'spoken': 91,
#  'dialogue': 8,
#  'study': 244,
#  'published': 203,
#  'genetic': 39,
#  'diversity': 28,
#  'codependent': 1,
#  'Dambusters': 2,
#  'raid': 16,
#  'samurai': 35,
#  'wives': 15,
#  'learned': 20,
#  'read': 47,
#  'granted': 62,
#  'Japanese': 141,
#  'wrestling': 32,
#  'differ': 25,
#  'doctrine': 28,
#  'describes': 63,
#  'belief': 59,
#  'Mary': 121,
#  'remained': 34,
#  'virgin': 10,
#  'even': 58,
#  'though': 25,
#  'she': 129,
#  'gave': 111,
#  'birth': 61,
#  'Jesus': 88,
#  'revenues': 13,
#  'under': 298,
#  '4': 56,
#  'years': 436,
#  'Watson': 7,
#  'being': 456,
#  'president': 220,
#  'end': 373,
#  'Central': 53,
#  'Europe': 211,
#  'tribes': 52,
#  'invade': 62,
#  'Roman': 272,
#  'Empire': 260,
#  'icon': 8,
#  'Mexico': 187,
#  'Royal': 109,
#  'Shell': 65,
#  'Group': 37,
#  'Created': 1,
#  'Cubs': 26,
#  'leaving': 27,
#  'Side': 4,
#  'Grounds': 1,
#  'To': 234,
#  'style': 227,
#  'poet': 18,
#  'Seattle': 145,
#  'consider': 81,
#  'itself': 69,
#  'home': 197,
#  'color': 204,
#  'uniform': 17,
#  'Napoleon': 272,
#  'usually': 191,
#  'wore': 7,
#  'Sundays': 3,
#  'reported': 82,
#  'Korea': 98,
#  'military': 286,
#  'ready': 20,
#  'combat': 31,
#  'organization': 227,
#  'Eisenhower': 202,
#  'want': 169,
#  'keep': 53,
#  'one': 917,
#  'McCarthy': 3,
#  'targets': 23,
#  'Zealand': 25,
#  'Mr': 19,
#  'White': 32,
#  'ask': 28,
#  'Bond': 33,
#  'protect': 54,
#  'nursing': 3,
#  'homes': 42,
#  'HHC': 11,
#  'operate': 68,
#  'annexed': 20,
#  'Estonia': 116,
#  'Estonian': 50,
#  'SSR': 5,
#  'Russia': 92,
#  'Van': 11,
#  'Halen': 7,
#  'instrumental': 11,
#  'showcased': 3,
#  'guitar': 8,
#  'mastery': 1,
#  'Eddie': 1,
#  'agreement': 93,
#  'Britain': 214,
#  'kept': 51,
#  'Tibet': 78,
#  'Mayor': 24,
#  'Miami': 117,
#  'pardo': 1,
#  'include': 78,
#  'political': 269,
#  'ideology': 23,
#  'Gaddafi': 178,
#  'reject': 29,
#  'he': 398,
#  'attended': 44,
#  'Misrata': 3,
#  'Secondary': 2,
#  'School': 101,
#  'policy': 90,
#  'supplying': 2,
#  'arms': 25,
#  'materiel': 1,
#  'Vietnamese': 7,
#  '1940': 29,
#  'sleeping': 3,
#  'Underground': 11,
#  'stations': 74,
#  'Until': 36,
#  'Henry': 60,
#  'III': 71,
#  'continue': 48,
#  'attempts': 15,
#  'reclaim': 6,
#  'Normandy': 8,
#  'should': 159,
#  'conceptual': 5,
#  'model': 134,
#  'join': 98,
#  'United': 399,
#  'Nations': 57,
#  'sequenced': 7,
#  'bacterial': 12,
#  'genome': 38,
#  'large': 318,
#  'casinos': 4,
#  'Atlantic': 107,
#  'covers': 18,
#  'incorporated': 26,
#  'associations': 13,
#  'councils': 3,
#  'single': 147,
#  'Queen': 322,
#  'Innuendo': 1,
#  'charted': 3,
#  'UK': 131,
#  'area': 540,
#  'royal': 69,
#  'marines': 6,
#  'universities': 94,
#  'where': 440,
#  'departments': 11,
#  'educational': 33,
#  'psychology': 11,
#  'normally': 29,
#  'held': 309,
#  'narration': 1,
#  'literature': 66,
#  'blood': 31,
#  'lamb': 1,
#  'who': 754,
#  'b': 9,
#  'boy': 10,
#  'hip': 12,
#  'hop': 13,
#  'inspired': 46,
#  'detroit': 1,
#  'techno': 3,
#  'For': 231,
#  'Cruyff': 10,
#  'manager': 40,
#  'Barcelona': 141,
#  'residence': 34,
#  'halls': 7,
#  'University': 324,
#  'Opera': 18,
#  'Garnier': 2,
#  'specialize': 8,
#  'poultry': 31,
#  'consumable': 1,
#  'humans': 111,
#  'funny': 2,
#  'etching': 6,
#  'process': 205,
#  'blown': 2,
#  'solution': 17,
#  'moving': 30,
#  'around': 146,
#  'polish': 22,
#  'nobility': 22,
#  'compare': 54,
#  'heraldy': 1,
#  'liberal': 12,
#  'groups': 240,
#  'appearing': 8,
#  'this': 576,
#  'From': 215,
#  'rope': 4,
#  'tying': 2,
#  'Belavezha': 5,
#  'Accords': 6,
#  'signed': 94,
#  'radio': 103,
#  'format': 108,
#  'mixture': 9,
#  'urban': 41,
#  'soft': 32,
#  'adult': 71,
#  'contemporary': 68,
#  'pope': 52,
#  '1417': 1,
#  'Houston': 172,
#  '1890': 13,
#  'ago': 59,
#  'Man': 22,
#  'executed': 51,
#  'January': 73,
#  '17': 24,
#  '1977': 18,
#  'eulogy': 1,
#  'provided': 94,
#  'King': 123,
#  'completed': 50,
#  'benefited': 10,
#  'dogs': 134,
#  'hunt': 18,
#  'abolish': 4,
#  'Spain': 66,
#  '1813': 1,
#  'brother': 26,
#  'rule': 245,
#  'there': 513,
#  'Valdivia': 1,
#  'culture': 148,
#  'develop': 95,
#  'meters': 27,
#  'Sangamonian': 1,
#  'Stage': 3,
#  'raise': 28,
#  'sea': 94,
#  'levels': 64,
#  'compared': 105,
#  'present': 122,
#  'level': 127,
#  'Uralic': 3,
#  'branch': 83,
#  'contains': 62,
#  'S': 278,
#  'share': 101,
#  'China': 235,
#  'IndyMac': 19,
#  'loans': 23,
#  'without': 105,
#  'verifying': 1,
#  'province': 56,
#  'capital': 186,
#  'act': 114,
#  'due': 149,
#  'morality': 7,
#  'summoned': 6,
#  'Everyman': 2,
#  'Parallel': 2,
#  'Lives': 2,
#  'dynasty': 141,
#  'followed': 33,
#  'era': 218,
#  'Mughals': 3,
#  'medical': 54,
#  'group': 619,
#  'Brigades': 1,
#  'but': 117,
#  'plant': 139,
#  'grows': 10,
#  'rocky': 1,
#  'areas': 212,
#  'Council': 117,
#  'Trent': 8,
#  'agree': 51,
#  'corrected': 5,
#  'calendar': 57,
#  'limitations': 3,
#  'Greg': 7,
#  'analyses': 3,
#  'seats': 25,
#  'Provincial': 7,
#  'Assembly': 32,
#  'languages': 178,
#  'employed': 46,
#  'Manichaeans': 1,
#  'Libya': 70,
#  'gross': 24,
#  'domestic': 49,
#  'product': 76,
#  'increase': 169,
#  '1969': 21,
#  '1979': 25,
#  'Keynes': 2,
#  'arguments': 7,
#  'against': 357,
#  'Austrian': 23,
#  'theory': 175,
#  'business': 126,
#  'cycle': 19,
#  'eventually': 69,
#  'influence': 135,
#  'Hall': 64,
#  'Mountain': 16,
#  'conjointly': 1,
#  'attempting': 15,
#  'hub': 16,
#  'two': 877,
#  'industries': 34,
#  'Did': 118,
#  'emperor': 54,
#  'disagree': 13,
#  'Arians': 7,
#  'Soviets': 26,
#  'detonate': 2,
#  'nuclear': 48,
#  'bomb': 31,
#  'abbot': 2,
#  'town': 90,
#  'built': 287,
#  'abbey': 39,
#  'Muslims': 44,
#  'converted': 37,
#  'Christianity': 45,
#  'according': 110,
#  'poll': 11,
#  'global': 38,
#  'publisher': 15,
#  'utilizes': 3,
#  'sentence': 28,
#  'case': 106,
#  'titles': 39,
#  'headers': 1,
#  'Labour': 14,
#  'Social': 13,
#  'Welfare': 1,
#  'institute': 23,
#  'Hesburgh': 6,
#  'given': 275,
#  'credit': 40,
#  'creating': 41,
#  'Notre': 181,
#  'Dame': 183,
#  'tectonics': 3,
#  'Microsoft': 46,
#  'describe': 154,
#  'Kinect': 6,
#  'lawful': 2,
#  'hunting': 92,
#  'distinguished': 22,
#  'poaching': 3,
#  'county': 92,
#  'football': 162,
#  'team': 302,
#  'satellite': 69,
#  'Nigeria': 114,
#  'fourth': 45,
#  'replace': 50,
#  'examples': 96,
#  'Iranian': 55,
#  'visual': 16,
#  'art': 149,
#  ...}

# %%
most_common_words = sorted(words_count.items(), key=lambda x: x[1], reverse=True)[:3]

# %%
most_common_words
# Out:
# [('the', 44111), ('What', 26685), ('of', 24402)]

# %%
WORDS_TO_INDEX = {}
INDEX_TO_WORDS = {}
idx = 0
for w in words_count.keys():
    WORDS_TO_INDEX[w] = idx
    INDEX_TO_WORDS[idx] = w
    idx += 1

# %%
ALL_WORDS = WORDS_TO_INDEX.keys()

# %%
DICT_SIZE = len(ALL_WORDS)

# %%
DICT_SIZE
# Out:
# 35525

# %%
def bag_of_words(text, words_to_index, dict_size):
    result_vector = np.zeros(dict_size)
    for w in text.split():
        if w in words_to_index:
            result_vector[words_to_index[w]] = 1
    return result_vector

# %%
print(bag_of_words('how was your day',{'hi':1,'how':2,'day':3},5))
# Out:
# [0. 0. 1. 1. 0.]

# %%
from scipy import sparse as sp_sparse

# %%
X_train_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in X_train])
# Out:
# X_train shape  (62352, 35525)

# %%
print('Bag ofwords : X_train shape : {} '.format(X_train_mybag.shape))
# Out:
# Bag ofwords : X_train shape : (62352, 35525)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def tfidf_features(X):
    tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 2))
    X = tfidf_vectorizer.fit_transform(X)
    return X,tfidf_vectorizer

# %%
X_train_tfidf,tfidf_vectorizer = tfidf_features(X_train)
print('X_train shape ', X_train_tfidf.shape)
# Out:
# X_train shape  (62352, 31269)
# C:\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1059: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
print('TF_IDF : X_train shape : {} '.format(X_train_tfidf.shape))
# Out:
# TF_IDF : X_train shape : (62352, 31269)

# %%
DOCUMENT_IDS = {}
for y in Y_train:
    if y not in DOCUMENT_IDS:
        DOCUMENT_IDS[y] = 1
    else:
        DOCUMENT_IDS[y] += 1

# %%
DOCUMENT_IDS
# Out:
# {'4296602a1bfe11ea8f2b656571b1b549': 6,
#  '42840a9c1bfe11ea8f2b656571b1b549': 4,
#  '4277df561bfe11ea8f2b656571b1b549': 15,
#  '42902d7c1bfe11ea8f2b656571b1b549': 7,
#  '4272a11c1bfe11ea8f2b656571b1b549': 4,
#  '4298c7e81bfe11ea8f2b656571b1b549': 3,
#  '4282bf2a1bfe11ea8f2b656571b1b549': 3,
#  '428ec63a1bfe11ea8f2b656571b1b549': 4,
#  '42920a661bfe11ea8f2b656571b1b549': 4,
#  '427d4cac1bfe11ea8f2b656571b1b549': 3,
#  '4271735a1bfe11ea8f2b656571b1b549': 4,
#  '4291fc921bfe11ea8f2b656571b1b549': 7,
#  '427181c41bfe11ea8f2b656571b1b549': 4,
#  '4280e0921bfe11ea8f2b656571b1b549': 8,
#  '4278c5a61bfe11ea8f2b656571b1b549': 8,
#  '429724601bfe11ea8f2b656571b1b549': 12,
#  '4293466a1bfe11ea8f2b656571b1b549': 4,
#  '4281b36e1bfe11ea8f2b656571b1b549': 3,
#  '4277a7021bfe11ea8f2b656571b1b549': 9,
#  '426df11c1bfe11ea8f2b656571b1b549': 7,
#  '4272d9201bfe11ea8f2b656571b1b549': 6,
#  '42884d001bfe11ea8f2b656571b1b549': 4,
#  '426bd2101bfe11ea8f2b656571b1b549': 4,
#  '427549581bfe11ea8f2b656571b1b549': 7,
#  '428d00e81bfe11ea8f2b656571b1b549': 3,
#  '4298dd641bfe11ea8f2b656571b1b549': 10,
#  '42960f6c1bfe11ea8f2b656571b1b549': 4,
#  '427fa2541bfe11ea8f2b656571b1b549': 4,
#  '427ea0841bfe11ea8f2b656571b1b549': 4,
#  '429315d21bfe11ea8f2b656571b1b549': 4,
#  '427a748c1bfe11ea8f2b656571b1b549': 4,
#  '427749b01bfe11ea8f2b656571b1b549': 4,
#  '427184c61bfe11ea8f2b656571b1b549': 4,
#  '428f57c61bfe11ea8f2b656571b1b549': 4,
#  '427ac37e1bfe11ea8f2b656571b1b549': 3,
#  '429660ca1bfe11ea8f2b656571b1b549': 3,
#  '4296adc81bfe11ea8f2b656571b1b549': 8,
#  '4283ab601bfe11ea8f2b656571b1b549': 4,
#  '42835aac1bfe11ea8f2b656571b1b549': 3,
#  '4294493e1bfe11ea8f2b656571b1b549': 7,
#  '427878e41bfe11ea8f2b656571b1b549': 4,
#  '426ea2601bfe11ea8f2b656571b1b549': 4,
#  ...}

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
mlb = LabelBinarizer()
Y_train_label = mlb.fit_transform(Y_train)

# %%
len(Y_train_label)
# Out:
# 62352

# %%
from sklearn import linear_model
from sklearn import metrics

# %%
lr = linear_model.LogisticRegression(C = 0.6, random_state = 1
                            , n_jobs = 8, solver="saga")
lr.fit(X_train_mybag, Y_train_label)
y_train_predicted_label = lr.predict(X_train_tfidf)

print("Training accuracy: ", metrics.accuracy_score(y_train_predicted_label, Y_train_label))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-921439e4a0c8> in <module>()
#       1 lr = linear_model.LogisticRegression(C = 0.6, random_state = 1
#       2                             , n_jobs = 8, solver="saga")
# ----> 3 lr.fit(X_train_mybag, Y_train_label)
#       4 y_train_predicted_label = lr.predict(X_train_tfidf)
#       5
#
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1171
#    1172         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1173                          order="C")
#    1174         check_classification_targets(y)
#    1175         self.classes_ = np.unique(y)
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     524                         dtype=None)
#     525     else:
# --> 526         y = column_or_1d(y, warn=True)
#     527         _assert_all_finite(y)
#     528     if y_numeric and y.dtype.kind == 'O':
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in column_or_1d(y, warn)
#     560         return np.ravel(y)
#     561
# --> 562     raise ValueError("bad input shape {0}".format(shape))
#     563
#     564
#
# ValueError: bad input shape (62352, 15280)

# %%
from sklearn import tree

# %%
est = tree.DecisionTreeClassifier()
est.fit(X_train_tfidf, Y_train_label)

# %%
print("")print
